# %%
import pandas as pd
import time
pd.set_option('display.max_rows', None)

# %%
standings_2025 = pd.read_html('https://www.mlb.com/standings/mlb?date=2025-07-15')
standings_2025 = pd.concat(standings_2025)
standings_2025 = standings_2025.rename(columns={'American League':'TEAM'})
standings_2025 = standings_2025[standings_2025.iloc[:, 0] != 'National League']
standings_2025["TEAM"][25] = "Athletics Athletics"


stats_2025 = pd.read_html("https://www.espn.com/mlb/stats/rpi/_/year/2025/sort/sos")
stats_2025 = pd.concat(stats_2025)
stats_2025 = stats_2025[2:]
stats_2025 = stats_2025.rename(columns={1:'TEAM'})


new_standings_2025 = pd.merge(standings_2025, stats_2025, on = 'TEAM', how = 'inner')
new_standings_2025 = new_standings_2025.rename(columns={2:'RPI', 6:'SOS',
                                                        10: 'EXPW-L', 11:'EXPWP'}).drop(columns=[0,3,4,5,7,8,9,12,'Next Game', 'STRK','L10'])
new_standings_2025['Home_Win_PCT'] = round((new_standings_2025['HOME'].str.split('-').str[0].astype(int) /(new_standings_2025['HOME'].str.split('-').str[0].astype(int) +
                                                                                                    new_standings_2025['HOME'].str.split('-').str[1].astype(int))), 3)

new_standings_2025['Away_Win_PCT'] = round((new_standings_2025['AWAY'].str.split('-').str[0].astype(int) /(new_standings_2025['AWAY'].str.split('-').str[0].astype(int) +
                                                                                                    new_standings_2025['AWAY'].str.split('-').str[1].astype(int))), 3)

# %%
new_standings_2025['Year'] = 2025
new_standings_2025.to_csv('standings_2025_before_all_star.csv')

# %%
x =[]
all_star_dates = [
    "2024-07-17",
    "2023-07-13",
    "2022-07-19",
    "2021-07-14",
    '2020-09-13',
    "2019-07-08",
    "2018-07-16",
    "2017-07-10",
    "2016-07-11",
    "2015-07-13",
    "2014-07-14",
    "2013-07-17",
    "2012-07-09",
    "2011-07-11",
    "2010-07-12",
    "2009-07-13",
    "2008-07-14",
    "2007-07-09",
    "2006-07-10"
]

for i in range(1, 20):
  year = 2025 - i
  try:
    # Scrape standings from MLB
    standings_x = pd.read_html(f'https://www.mlb.com/standings/league/{year}?date={all_star_dates[i-1]}')
    standings_x = pd.concat(standings_x)
    standings_x = standings_x.rename(columns={'American League':'TEAM'})
    standings_x = standings_x[standings_x.iloc[:, 0] != 'National League']
    standings_x['Year'] = year
    standings_x['TEAM'] = standings_x['TEAM'].str.rstrip('zwyZWY')

    # Sleep before next request
    time.sleep(2)

    # Scrape RPI stats from ESPN
    stats_x = pd.read_html(f"https://www.espn.com/mlb/stats/rpi/_/year/{year}/sort/sos")
    stats_x = pd.concat(stats_x)
    stats_x = stats_x[2:]  # Skip header rows
    stats_x = stats_x.rename(columns={1: 'TEAM'})

    # Merge the two datasets
    new_standings_x = pd.merge(standings_x, stats_x, on='TEAM', how='inner')
    new_standings_x = new_standings_x.rename(columns={2:'RPI', 6:'SOS',
                                                      10: 'EXPW-L', 11:'EXPWP'}).drop(columns=[0,3,4,5,7,8,9,12, 'STRK','L10'])
    new_standings_x['Home_Win_PCT'] = round((new_standings_x['HOME'].str.split('-').str[0].astype(int) /(new_standings_x['HOME'].str.split('-').str[0].astype(int) +
                                                                                                    new_standings_x['HOME'].str.split('-').str[1].astype(int))), 3)
    new_standings_x['Away_Win_PCT'] = round((new_standings_x['AWAY'].str.split('-').str[0].astype(int) /(new_standings_x['AWAY'].str.split('-').str[0].astype(int) +
                                                                                                    new_standings_x['AWAY'].str.split('-').str[1].astype(int))), 3)
    x.append(new_standings_x)

    # Sleep again before the next year
    time.sleep(3)

  except Exception as e:
    print(f"Failed for year {year}: {e}")
    continue

# %%
x_remove = x[(x['Year'] != 2022) & (x['Year'] != 2019)]
# Out:
# array([2024, 2023, 2021, 2020, 2018, 2017, 2016, 2015, 2014, 2013, 2012,
#        2011, 2010, 2009, 2008, 2007, 2006])

# %%
standings_2022 = pd.read_html('https://www.mlb.com/standings/league/2022?date=2022-07-18')
standings_2022 = pd.concat(standings_2022)
standings_2022 = standings_2022.rename(columns={'American League':'TEAM'})
standings_2022 = standings_2022[standings_2022.iloc[:, 0] != 'National League']


stats_2022 = pd.read_html("https://www.espn.com/mlb/stats/rpi/_/year/2022/sort/sos")
stats_2022 = pd.concat(stats_2022)
stats_2022 = stats_2022[2:]
stats_2022 = stats_2022.rename(columns={1:'TEAM'})


new_standings_2022 = pd.merge(standings_2022, stats_2022, on = 'TEAM', how = 'inner')
new_standings_2022 = new_standings_2022.rename(columns={2:'RPI', 6:'SOS',
                                                        10: 'EXPW-L', 11:'EXPWP'}).drop(columns=[0,3,4,5,7,8,9,12,'STRK','L10'])
new_standings_2022['Home_Win_PCT'] = round((new_standings_2022['HOME'].str.split('-').str[0].astype(int) /(new_standings_2022['HOME'].str.split('-').str[0].astype(int) +
                                                                                                    new_standings_2022['HOME'].str.split('-').str[1].astype(int))), 3)

new_standings_2022['Away_Win_PCT'] = round((new_standings_2022['AWAY'].str.split('-').str[0].astype(int) /(new_standings_2022['AWAY'].str.split('-').str[0].astype(int) +
                                                                                                    new_standings_2022['AWAY'].str.split('-').str[1].astype(int))), 3)

new_standings_2022

new_standings_2022['Year'] = 2022
# Out:
#                      TEAM   W   L   PCT    GB  WCGB   RS   RA  DIFF  X-W/L  \
# 0        New York Yankees  64  28  .696     -     -  497  298  +199  66-26
# 1          Houston Astros  59  32  .648   4.5     -  403  305   +98  57-34
# 2          Tampa Bay Rays  51  41  .554  13.0  +1.5  388  359   +29  49-43
# 3        Seattle Mariners  51  42  .548  13.5  +1.0  385  349   +36  51-42
# 4       Toronto Blue Jays  50  43  .538  14.5     -  428  404   +24  49-44
# 5         Minnesota Twins  50  44  .532  15.0     -  421  393   +28  50-44
# 6          Boston Red Sox  48  45  .516  16.5   2.0  430  412   +18  48-45
# 7     Cleveland Guardians  46  44  .511  17.0   2.5  391  386    +5  46-44
# 8       Baltimore Orioles  46  46  .500  18.0   3.5  386  393    -7  45-47
# 9       Chicago White Sox  46  46  .500  18.0   3.5  406  420   -14  45-47
# 10          Texas Rangers  41  49  .456  22.0   7.5  406  407    -1  45-45
# 11     Los Angeles Angels  39  53  .424  25.0  10.5  363  393   -30  43-49
# 12         Detroit Tigers  37  55  .402  27.0  12.5  288  400  -112  33-59
# 13     Kansas City Royals  36  56  .391  28.0  13.5  359  469  -110  35-57
# 14      Oakland Athletics  32  61  .344  32.5  18.0  306  424  -118  33-60
# 15    Los Angeles Dodgers  60  30  .667     -     -  462  293  +169  63-27
# 16          New York Mets  58  35  .624   3.5     -  437  354   +83  55-38
# 17         Atlanta Braves  56  38  .596   6.0  +6.0  446  374   +72  55-39
# 18       San Diego Padres  52  42  .553  10.0  +2.0  408  377   +31  50-44
# 19      Milwaukee Brewers  50  43  .538  11.5     -  417  392   +25  49-44
# 20  Philadelphia Phillies  49  43  .533  12.0     -  431  369   +62  52-40
# 21    St. Louis Cardinals  50  44  .532  12.0     -  431  366   +65  54-40
# 22   San Francisco Giants  48  43  .527  12.5   0.5  437  386   +51  51-40
# 23          Miami Marlins  43  48  .473  17.5   5.5  371  383   -12  44-47
# 24       Colorado Rockies  43  50  .462  18.5   6.5  427  489   -62  41-52
# 25   Arizona Diamondbacks  40  52  .435  21.0   9.0  383  436   -53  41-51
# 26     Pittsburgh Pirates  39  54  .419  22.5  10.5  340  474  -134  33-60
# 27           Chicago Cubs  35  57  .380  26.0  14.0  386  472   -86  38-54
# 28        Cincinnati Reds  34  57  .374  26.5  14.5  390  497  -107  36-55
# 29   Washington Nationals  31  63  .330  31.0  19.0  364  513  -149  33-61
#
#      HOME   AWAY  >.500   RPI   SOS  EXPW-L EXPWP  Home_Win_PCT  Away_Win_PCT
# 0   37-12  27-16  43-23  .535  .509  108-54  .670         0.755         0.628
# 1   28-14  31-18  23-16  .534  .494  108-54  .669         0.667         0.633
# 2   31-18  20-23  35-29  .514  .508   88-74  .541         0.633         0.465
# 3   24-20  27-22  27-30  .511  .496   89-73  .551         0.545         0.551
# 4   30-19  20-24  32-35  .524  .510   92-70  .566         0.612         0.455
# 5   27-22  23-22  29-29  .492  .496   82-80  .509         0.551         0.511
# 6   23-20  25-25  30-36  .502  .509   75-87  .466         0.535         0.500
# 7   25-19  21-25  22-25  .510  .490   89-73  .548         0.568         0.457
# 8   25-17  21-29  28-35  .508  .506   79-83  .490         0.595         0.420
# 9   19-25  27-21  28-32  .493  .491   77-85  .478         0.432         0.562
# 10  21-26  20-23  22-34  .479  .499   77-85  .475         0.447         0.465
# 11  22-27  17-26  24-42  .491  .504   75-87  .465         0.449         0.395
# 12  23-24  14-31  24-39  .473  .495  61-101  .379         0.489         0.311
# 13  19-27  17-29  21-41  .475  .499  62-100  .384         0.413         0.370
# 14  11-31  21-30  20-45  .471  .504  57-105  .352         0.262         0.412
# 15  30-13  30-17  23-17  .545  .499  119-43  .732         0.698         0.638
# 16  28-15  30-20  28-22  .532  .502  100-62  .619         0.651         0.600
# 17  31-20  25-18  22-21  .529  .497  102-60  .627         0.608         0.581
# 18  25-21  27-21  22-26  .515  .504   86-76  .533         0.543         0.562
# 19  21-19  29-24  23-26  .500  .490   85-77  .526         0.525         0.547
# 20  24-21  25-22  25-29  .511  .502   88-74  .543         0.533         0.532
# 21  29-20  21-24  23-31  .510  .489   96-66  .595         0.592         0.467
# 22  26-22  22-21  23-24  .501  .502   83-79  .513         0.542         0.512
# 23  22-22  21-26  23-35  .486  .506   70-92  .429         0.500         0.447
# 24  28-23  15-27  19-30  .485  .507   63-99  .390         0.549         0.357
# 25  22-26  18-26  18-32  .493  .504   77-85  .474         0.458         0.409
# 26  20-23  19-31  15-32  .468  .496  56-106  .344         0.465         0.380
# 27  18-32  17-25  21-40  .485  .494   72-90  .447         0.360         0.405
# 28  18-28  16-29  21-40  .467  .495   63-99  .387         0.391         0.356
# 29  15-36  16-27  15-38  .463  .504  54-108  .332         0.294         0.372

# %%
standings_2019 = pd.read_html('https://www.mlb.com/standings/league/2019?date=2019-07-10')
standings_2019 = pd.concat(standings_2019)
standings_2019 = standings_2019.rename(columns={'American League':'TEAM'})
standings_2019 = standings_2019[standings_2019.iloc[:, 0] != 'National League']


stats_2019 = pd.read_html("https://www.espn.com/mlb/stats/rpi/_/year/2019/sort/sos")
stats_2019 = pd.concat(stats_2019)
stats_2019 = stats_2019[2:]
stats_2019 = stats_2019.rename(columns={1:'TEAM'})


new_standings_2019 = pd.merge(standings_2019, stats_2019, on = 'TEAM', how = 'inner')
new_standings_2019 = new_standings_2019.rename(columns={2:'RPI', 6:'SOS',
                                                        10: 'EXPW-L', 11:'EXPWP'}).drop(columns=[0,3,4,5,7,8,9,12,'STRK','L10'])
new_standings_2019['Home_Win_PCT'] = round((new_standings_2019['HOME'].str.split('-').str[0].astype(int) /(new_standings_2019['HOME'].str.split('-').str[0].astype(int) +
                                                                                                    new_standings_2019['HOME'].str.split('-').str[1].astype(int))), 3)

new_standings_2019['Away_Win_PCT'] = round((new_standings_2019['AWAY'].str.split('-').str[0].astype(int) /(new_standings_2019['AWAY'].str.split('-').str[0].astype(int) +
                                                                                                    new_standings_2019['AWAY'].str.split('-').str[1].astype(int))), 3)

new_standings_2019
new_standings_2019['Year'] = 2019
# Out:
#                      TEAM   W   L   PCT    GB  WCGB   RS   RA  DIFF  X-W/L  \
# 0        New York Yankees  57  31  .648     -     -  503  390  +113  54-34
# 1          Houston Astros  57  33  .633   1.0     -  458  367   +91  54-36
# 2         Minnesota Twins  56  33  .629   1.5     -  509  393  +116  55-34
# 3          Tampa Bay Rays  52  39  .571   6.5  +0.5  415  335   +80  54-37
# 4       Cleveland Indians  50  38  .568   7.0     -  396  369   +27  47-41
# 5       Oakland Athletics  51  41  .554   8.0   1.0  469  400   +69  53-39
# 6          Boston Red Sox  49  41  .544   9.0   2.0  509  451   +58  50-40
# 7           Texas Rangers  48  42  .533  10.0   3.0  485  461   +24  47-43
# 8      Los Angeles Angels  45  46  .495  13.5   6.5  457  460    -3  45-46
# 9       Chicago White Sox  42  44  .488  14.0   7.0  378  449   -71  36-50
# 10       Seattle Mariners  39  55  .415  21.0  14.0  479  550   -71  41-53
# 11      Toronto Blue Jays  34  57  .374  24.5  17.5  393  477   -84  38-53
# 12     Kansas City Royals  30  61  .330  28.5  21.5  382  472   -90  37-54
# 13         Detroit Tigers  28  58  .326  28.0  21.0  311  472  -161  27-59
# 14      Baltimore Orioles  27  62  .303  30.5  23.5  375  540  -165  30-59
# 15    Los Angeles Dodgers  60  32  .652     -     -  480  351  +129  59-33
# 16         Atlanta Braves  54  37  .593   5.5     -  491  432   +59  51-40
# 17   Washington Nationals  47  42  .528  11.5  +0.5  440  411   +29  47-42
# 18           Chicago Cubs  47  43  .522  12.0     -  455  400   +55  50-40
# 19  Philadelphia Phillies  47  43  .522  12.0     -  442  440    +2  45-45
# 20      Milwaukee Brewers  47  44  .516  12.5   0.5  432  449   -17  44-47
# 21   Arizona Diamondbacks  46  45  .505  13.5   1.5  464  411   +53  51-40
# 22       San Diego Padres  45  45  .500  14.0   2.0  402  437   -35  42-48
# 23    St. Louis Cardinals  44  44  .500  14.0   2.0  393  391    +2  44-44
# 24       Colorado Rockies  44  45  .494  14.5   2.5  490  488    +2  45-44
# 25     Pittsburgh Pirates  44  45  .494  14.5   2.5  432  468   -36  41-48
# 26        Cincinnati Reds  41  46  .471  16.5   4.5  368  341   +27  47-40
# 27   San Francisco Giants  41  48  .461  17.5   5.5  369  439   -70  37-52
# 28          New York Mets  40  50  .444  19.0   7.0  420  466   -46  41-49
# 29          Miami Marlins  33  55  .375  25.0  13.0  312  399   -87  34-54
#
#      HOME   AWAY  >.500   RPI   SOS  EXPW-L EXPWP  Home_Win_PCT  Away_Win_PCT
# 0   31-14  26-17  23-15  .529  .494  100-62  .620         0.689         0.605
# 1   33-14  24-19  30-21  .541  .501  109-53  .674         0.702         0.558
# 2   28-15  28-18  19-18  .518  .482   98-64  .608         0.651         0.609
# 3   26-22  26-17  25-27  .517  .492   94-68  .579         0.542         0.605
# 4   25-18  25-20  14-19  .505  .482   94-68  .578         0.581         0.556
# 5   26-20  25-21  23-19  .524  .499   98-64  .607         0.565         0.543
# 6   20-22  29-19  17-25  .499  .493   88-74  .542         0.476         0.604
# 7   29-17  19-25  18-23  .497  .502   74-88  .460         0.630         0.432
# 8   22-21  23-25  24-33  .491  .506   71-91  .440         0.512         0.479
# 9   25-20  17-24  21-29  .479  .489   68-93  .420         0.556         0.415
# 10  19-29  20-26  21-46  .482  .502   68-94  .419         0.396         0.435
# 11  18-30  16-27  20-33  .478  .500   70-92  .435         0.375         0.372
# 12  16-28  14-33  18-35  .459  .491   63-99  .387         0.364         0.298
# 13  12-33  16-25  12-37  .440  .489  46-115  .288         0.267         0.390
# 14  11-31  16-31  14-44  .459  .501  58-104  .356         0.262         0.340
# 15  37-12  23-20  30-21  .540  .502  110-52  .676         0.755         0.535
# 16  28-19  26-18  24-23  .524  .499   92-70  .570         0.596         0.591
# 17  26-20  21-22  19-22  .518  .499   96-66  .592         0.565         0.488
# 18  29-16  18-27  24-24  .508  .504   91-71  .563         0.644         0.400
# 19  27-17  20-26  23-26  .503  .503   79-83  .487         0.614         0.435
# 20  27-18  20-26  21-22  .519  .509   81-81  .502         0.600         0.435
# 21  20-22  26-23  23-29  .509  .504   88-74  .545         0.476         0.531
# 22  23-24  22-21  26-19  .487  .506   69-93  .428         0.489         0.512
# 23  24-18  20-26  22-28  .519  .505   93-69  .571         0.571         0.435
# 24  24-19  20-26  30-34  .492  .510   70-92  .432         0.558         0.435
# 25  22-21  22-24  29-37  .485  .505   66-96  .409         0.512         0.478
# 26  24-21  17-25  29-32  .496  .508   80-82  .493         0.533         0.405
# 27  20-26  21-22  25-32  .500  .509   70-92  .435         0.435         0.488
# 28  23-19  17-31  27-42  .512  .506   87-75  .535         0.548         0.354
# 29  15-29  18-26  22-42  .470  .510  59-103  .367         0.341         0.409

# %%
new_standings_2022['Year'] = 2022
new_standings_2019['Year'] = 2019

standings_2006_2024 = pd.concat([new_standings_2022, new_standings_2019, x_remove])
standings_2006_2024 = standings_2006_2024[standings_2006_2024['Year'] != 2020]
standings_2006_2024.to_csv('standings_2006_2024_before_all_star.csv')

# %%
end_season = []

for i in range(1, 20):
  year = 2025 - i
  try:
    # Scrape standings from MLB
    standings_x = pd.read_html(f'https://www.mlb.com/standings/league/{year}')
    standings_x = pd.concat(standings_x)
    standings_x = standings_x.rename(columns={'American League':'TEAM'})
    standings_x = standings_x[standings_x.iloc[:, 0] != 'National League']
    standings_x['Year'] = year
    standings_x['TEAM'] = standings_x['TEAM'].str.rstrip('zwyZWY')

    # Sleep before next request
    time.sleep(2)

    # Scrape RPI stats from ESPN
    stats_x = pd.read_html(f"https://www.espn.com/mlb/stats/rpi/_/year/{year}/sort/sos")
    stats_x = pd.concat(stats_x)
    stats_x = stats_x[2:]  # Skip header rows
    stats_x = stats_x.rename(columns={1: 'TEAM'})

    # Merge the two datasets
    new_standings_x = pd.merge(standings_x, stats_x, on='TEAM', how='inner')
    new_standings_x = new_standings_x.rename(columns={2:'RPI', 6:'SOS',
                                                      10: 'EXPW-L', 11:'EXPWP'}).drop(columns=[0,3,4,5,7,8,9,12, 'STRK','L10'])
    new_standings_x['Home_Win_PCT'] = round((new_standings_x['HOME'].str.split('-').str[0].astype(int) /(new_standings_x['HOME'].str.split('-').str[0].astype(int) +
                                                                                                    new_standings_x['HOME'].str.split('-').str[1].astype(int))), 3)
    new_standings_x['Away_Win_PCT'] = round((new_standings_x['AWAY'].str.split('-').str[0].astype(int) /(new_standings_x['AWAY'].str.split('-').str[0].astype(int) +
                                                                                                    new_standings_x['AWAY'].str.split('-').str[1].astype(int))), 3)
    end_season.append(new_standings_x)

    # Sleep again before the next year
    time.sleep(3)

  except Exception as e:
    print(f"Failed for year {year}: {e}")
    continue

# %%
end_season_df = pd.concat(end_season)
end_season_df_final = end_season_df[end_season_df['Year'] != 2020]
end_season_df_final.to_csv('end_season_standings_2006_2024.csv')
